# %% [markdown]
# 3.	Write a program to print the multiplication table of the number entered by the user. The table should get displayed in the following form.
# 29 * 1 = 29
# 29	*2 = 58

# %%
num=int(raw_input("Enter the number: "))
for i in range(1,11):
       print("%d * %d = %d"%(num,i,num*i))

# %% [markdown]
# 3.	WAP which repeatedly reads numbers until the user enters “done”. Once “done” is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number. (Use of list is not allowed in this program)
#
# Enter a number: 4
# Enter a number: 5
# Enter a number: nine
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16	3	5.33333333333

# %%
count=0
su=0
while True:
    
    i=raw_input('Enter a number: ')
    count+=1
    su=su+int(i)
    if i=='done':
        print("Sum =%d count=%d "%(su,count))

# %% [markdown]
# 5.	Guess a number is a game that prompts a player to guess a number between 0 and 9, which is randomly generated by the system. When the input given by the user matches the number generated by the system then the user wins. The game should go as follows:

# %% [markdown]
# 1.	WAP that will accept two sets of numbers and calculate the Pearson’s correlation coefficient between them. (Use necessary exception handling). (Optional if you do not know what it is)

# %%
import numpy as np
import math 
a=[]
b=[]
for i in range(0,3):
    a.append (int(input("Enter 3 numbers :")))
for i in range(0,3):
    b.append (int(input("Enter the second set of number numbers :")))
x=np.array(a)
y=np.array(b)
sum_x=np.sum(x)
sum_y=np.sum(y)
sum_x_whole_square=np.sum(x)*np.sum(x)
sum_y_whole_square=np.sum(y)*np.sum(y)
sum_x_y=np.sum(x*y)
sum_x_square=np.sum(x*x)
sum_y_square=np.sum(y*y)
numerator=int(np.sum(x*y))-int((np.sum(x))(np.sum(y)))
numerator
# Out:
# Enter 3 numbers :1
# Enter 3 numbers :1
# Enter 3 numbers :1
# Enter the second set of number numbers :1
# Enter the second set of number numbers :1
# Enter the second set of number numbers :1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c2494b1bf60b> in <module>()
#      16 sum_x_square=np.sum(x*x)
#      17 sum_y_square=np.sum(y*y)
# ---> 18 numerator=int(np.sum(x*y))-int((np.sum(x))(np.sum(y)))
#      19 numerator
#      20
#
# TypeError: 'numpy.int32' object is not callable

# %%
# Out:
# 9.0

# %% [markdown]
# 5.	Guess a number is a game that prompts a player to guess a number between 0 and 9, which is randomly generated by the system. When the input given by the user matches the number generated by the system then the user wins. The game should go as follows:

# %%
import random
while True:
    a=raw_input("Guess the number")
    b=random.randint(0,9)
    if a==b:
        print("You win!")
        break
    else:
        print("Sorry guess again")

# %% [markdown]
# 6.	Make an improvement to the Guess a number game. Guide the user where they are standing and limit the number of attempts to 3. For example, the game should go like this:
# Guess the number: 4
# Too low
# Guess the number: 9
# Too high
# Guess the number: 5
# Sorry you Lost!

# %%
import random
count=0
while True:
    a=int(raw_input("Guess the number"))
    count+=1
    b=random.randint(0,9)
    if a==b:
        print("You win!")
        break
    elif b>a:
        print("Too low")
        print(b)    
    elif b<a:
        print("Too high")
        print(b)
    if count==3:
        print("sorry you lost")
        break
# Out:
# Guess the number1
# Too low
# 7
# Guess the number2
# Too low
# 6
# Guess the number5
# Too low
# 9
# sorry you lost

# %% [markdown]
# 7.	Let us make the above game a little more interesting by converting it into a gambling problem. Suppose that a player starts with Rs. 1,000. If a player can guess the number in his first chance, then he will be given a prize of Rs. 5,000, if he requires 2 attempts then he will get a prize of Rs.1,000. If he loses then he will lose Rs. 500. For example the game should go like this:
#
# You have a cash of Rs. 1,000 with you...
# Guess the number: 8
# Too high
# Guess the number: 3
# You have just won Rs. 1,000
# Your balance: Rs. 2000

# %%
import random
count=0
initial=1000
print("You have %d as your balance" %initial)
while True:
    a=int(raw_input("Guess the number"))
    count+=1
    b=random.randint(0,9)
    if count==1 and a==b:
        print("You win!")
        initial=initial+5000
        print("Your balance is %d " %initial)
        break
    if count==2 and a==b:
        print("You win!")
        initial=initial+1000
        print("Your balance is %d " %initial)
        break
    elif b>a:
        print("Too low")
        print(b)    
    elif b<a:
        print("Too high")
        print(b)
    if count==3:
        print("sorry you lost")
        initial=initial-500
        print("Your balance is %d "%initial)
        break
# Out:
# You have 1000 as your balance
# Guess the number2
# Too low
# 4
# Guess the number3
# Too low
# 9
# Guess the number4
# sorry you lost
# Your balance is 500

# %% [markdown]
# 3.	WAP which repeatedly reads numbers until the user enters “done”. Once “done” is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number. (Use of list is not allowed in this program)
#
# Enter a number: 4
# Enter a number: 5
# Enter a number: nine
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16	3	5.33333333333

# %%
count=0
su=0
while True:
    try:
        x=str(raw_input('Enter a number: '))
        if x=='done':
            print("Sum : %d Count: %d and Avg: %d" %(su,count,avg))
            break
        count+=1
        y=int(x)
        su=su+y
        avg=su/count
    except:
        print("Invalid input")
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: 6
# Enter a number: done
# Sum : 15 Count: 3 and Avg: 5

# %% [markdown]
# 4.	Write another program that prompts for a list of numbers as above and at the end prints both the maximum and minimum of the numbers instead of the average. (Use of list is not allowed in this program)

# %%
count=0
su=0
while True:
    try:
        x=str(raw_input('Enter a number: '))
        if x=='done':
            print("Sum : %d Count: %d" %(su,count))
            break
        count+=1
        y=int(x)
        su=su+y
    except:
        print("Invalid input")

# %%
x=int(raw_input('Enter a number: '))
Min=x
Max=x
while True:
    y=str(raw_input('Enter a number: '))
    if y=='done':
        print("minimum: %d Maximum: %d"%(Min,Max))
        break
    z=int(y)
    if z<Min:
        Min=z
    if z>Max:
        Max=z
# Out:
# Enter a number: 134
# Enter a number: 673
# Enter a number: 88
# Enter a number: 99
# Enter a number: 43
# Enter a number: done
# minimum: 43 Maximum: 673

# %%
for i in range(2,300):
    if i%i==0 and i%1=
