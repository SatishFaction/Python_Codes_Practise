# %%
import pandas as pd
import numpy as np
import os

# %%
Ca=pd.read_csv('cars.csv')
Ca.head(5)
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
Ca.Acceleration.describe()
# Out:
# count    406.000000
# mean      15.519704
# std        2.803359
# min        8.000000
# 25%       13.700000
# 50%       15.500000
# 75%       17.175000
# max       24.800000
# Name: Acceleration, dtype: float64

# %%
Ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
# Car             406 non-null object
# MPG             406 non-null float64
# Cylinders       406 non-null int64
# Displacement    406 non-null float64
# Horsepower      406 non-null int64
# Weight          406 non-null int64
# Acceleration    406 non-null float64
# Model           406 non-null int64
# Origin          406 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.6+ KB

# %%
Ca[["Acceleration","Origin"]].groupby(["Origin"]).mean()
# Out:
#         Acceleration
# Origin
# Europe     16.821918
# Japan      16.172152
# US         14.942520

# %%
Ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
# Car             406 non-null object
# MPG             406 non-null float64
# Cylinders       406 non-null int64
# Displacement    406 non-null float64
# Horsepower      406 non-null int64
# Weight          406 non-null int64
# Acceleration    406 non-null float64
# Model           406 non-null int64
# Origin          406 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.6+ KB

# %%
x=Ca[["Weight","Model"]].groupby(["Model"]).mean()
x.sort_values(by=['Weight'])
#x.columns
# Out:
#             Weight
# Model
# 80     2436.655172
# 82     2453.548387
# 81     2532.166667
# 78     2861.805556
# 74     2877.925926
# 71     2960.344828
# 77     2997.357143
# 79     3055.344828
# 76     3078.735294
# 75     3176.800000
# 72     3237.714286
# 73     3419.025000
# 70     3441.314286

# %%
t=pd.crosstab(Ca.Origin,columns=Ca.Cylinders)
t.sum()
# Out:
# Cylinders
# 3      4
# 4    207
# 5      3
# 6     84
# 8    108
# dtype: int64

# %%
Ca.sort_values("MPG",ascending=0).head(20)
# Out:
#                                    Car   MPG  Cylinders  Displacement  \
# 329                          Mazda GLC  46.6          4          86.0
# 336                Honda Civic 1500 gl  44.6          4          91.0
# 332       Volkswagen Rabbit C (Diesel)  44.3          4          90.0
# 402                  Volkswagen Pickup  44.0          4          97.0
# 333         Volkswagen Dasher (diesel)  43.4          4          90.0
# 251    Volkswagen Rabbit Custom Diesel  43.1          4          90.0
# 316                  Volkswagen Rabbit  41.5          4          98.0
# 337               Renault Lecar Deluxe  40.9          4          85.0
# 331                         Datsun 210  40.8          4          85.0
# 254                     Datsun B210 GX  39.4          4          85.0
# 350                     Toyota Starlet  39.1          4          79.0
# 351                     Plymouth Champ  39.0          4          86.0
# ...

# %%
Ca.Displacement.describe()
# Out:
# count    406.000000
# mean     194.779557
# std      104.922458
# min       68.000000
# 25%      105.000000
# 50%      151.000000
# 75%      302.000000
# max      455.000000
# Name: Displacement, dtype: float64

# %%
cross=pd.crosstab(Ca.Origin,columns='counts')
cross
list(cross)
# Out:
# ['counts']

# %%
Ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
# Car             406 non-null object
# MPG             406 non-null float64
# Cylinders       406 non-null int64
# Displacement    406 non-null float64
# Horsepower      406 non-null int64
# Weight          406 non-null int64
# Acceleration    406 non-null float64
# Model           406 non-null int64
# Origin          406 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.6+ KB
